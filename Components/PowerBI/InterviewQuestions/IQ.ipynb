# %% [markdown]
# **things to do**
#
# countrows,calculate learn others dax functions also.

# %% [markdown]
# **measure vs calculated columns**

# %% [markdown]
# calulated columns are a part of table it self, for example we needed to find discounted price for eaxh columns then we can use calc columns.
#
# where as measure is like a aggrigated value only, its not part of a table, ex: total cout of row countrows(tbl_name)

# %% [markdown]
# **How to handle missing data in Power BI**

# %% [markdown]
# - ignore the values
#
# - ask to the source
#
# - imputation by mean,median,mode

# %% [markdown]
# **what is DAX**

# %% [markdown]
# DAX stands for **data analysis expression**
#
# DAX is the main calculation mechanism of powerbi, we can calculate measures,columns as well as tables with DAX in powerbi.
#
# examples countrows,calculate learn others dax functions also.

# %% [markdown]
# **How to load data to powerbi**

# %% [markdown]
# file --> new source from there youcan load diffrent data sources.

# %% [markdown]
# **PowerBI Desktop vs service**

# %% [markdown]
# Power Bi desktop is mainly for creating reports by doing etl process, where power bi service helps to share our reports..power bi service is a consumtion tool where people who revie our reports can use service and desktop is a creating tool used by developers.

# %% [markdown]
# **How to optimize powerbi reports**

# %% [markdown]
# - remove excess bagagge: columns we are not using in reports from data source can be removed from source(sql,excel..etc)
#
# - remove unnessary visuals
#
# - under optimize menu --> perforamnce analyser: we can see the performance for every visuals.
#
# - using aggrigate tables rather than using row tables for visuals.

# %% [markdown]
# **what is the diffrents between append and merge**

# %% [markdown]
# **append** is like union in sql, its add data in row wise, structure of both tables/querries have to be same
#
# **merge** is like sql joins , inner,left,right,full join.

# %% [markdown]
# **What is query folding**

# %% [markdown]
# https://www.youtube.com/watch?v=_Pq6BrucFrg
#
# when we make tranformation using power query m language(power bi language) converts in to the source language this process is called query folding
#
# query folding source should be sql or some no sql etc exel and some other dont supp query folding
#
# also some steps cant be converted to source language, example change datatype of a field. in short we can say all steps which can fetch data from data source (sql) by using querries can be querry folded.
#
# https://learn.microsoft.com/en-us/power-query/query-folding-basics

# %% [markdown]
# ![queryfolding.png](attachment:queryfolding.png)

# %% [markdown]
# **Copying vs referenceing**

# %% [markdown]
# **copy** will create exact copy on original table but both table will be independent to each other.
#
# **reference** will still create exact copy of original but any change in original will reflect reference table also.

# %% [markdown]
# **A value 20210819 having whole number as datatype how to convert it into date datatype?**

# %% [markdown]
# step1: first convert to text datatype
#
# step2: then convert to date datatype.

# %% [markdown]
# **map vs filled map**

# %% [markdown]
# if have state and its profit data.
#
# map will give me bubbles over the states and buble size will differ according to the profit.
#
# filled map will fill with colours and each state will be filled with diffrent colours.
#
# filled map can be used like if i have see poluted area in a country , so i can give location as state,polution values in value, in legends "is poluted", then poluted area can be marked in same color.

# %% [markdown]
# **Column Chart**

# %% [markdown]
# For compairing **categorical vs numerical**
#
# X-axis: Categorical , Y-axis: Numerical
#
# Example: Category vs sales
#
# ![column_chart.png](attachment:column_chart.png)

# %% [markdown]
# **bar chart vs column chart**

# %% [markdown]
# bar chart and column chart are same
#
# - In bar chart is the horizontal version of column chart.
#
# - In bar chart **categorical col in y axis** and **numerical in x axis**
#
# ![col_chart_vs_bar_chart.png](attachment:col_chart_vs_bar_chart.png)

# %% [markdown]
# **stacked bar chart vs stacked column chart**

# %% [markdown]
# **stacked column chart:** if i need to show categorical vs numerical bifurcated with another categorical i can use this chart.
#
# - x axis: categorical col, y axis: Numerical, legend: categorical column which need to bifurcated with.
#
# **stacked bar chart:** its the horizontal version of stacked barchart
#
# - y axis: categorical col, x axis: Numerical, legend: categorical column which need to bifurcated with.
#
# ![stacked_bar_vs_stacked_column.png](attachment:stacked_bar_vs_stacked_column.png)
