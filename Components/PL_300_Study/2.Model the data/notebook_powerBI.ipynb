# %% [markdown]
# ## Relationship purpose

# %% [markdown]
# A model relationship propogate filter applied on column of one table to another table.
#
# Star schema:
#
# - dimention table
# - fact table
#
# Disconnected tables
#
# https://learn.microsoft.com/en-us/power-bi/transform-model/desktop-relationships-understand#relationship-purpose

# %% [markdown]
# ## Star Schema

# %% [markdown]
#     - what are the benefits of a good model ?
#
#     - how to design a model what things to take care ? (simplicity)
#
#     - how to make relationship between betwwen table ? (Foreign keys and Primary keys)
#
#     - what are the features of fact tables and dimention table ?
#
# https://learn.microsoft.com/en-us/training/modules/design-model-power-bi/1-introduction

# %% [markdown]
# ## Cardinality

# %% [markdown]
# - One-to-many (1:*)
# - Many-to-one (*:1)
# - One-to-one (1:1)
# - Many-to-many (*:*) helps to join two facts table

# %% [markdown]
# ## Cross filter direction

# %% [markdown]
# https://learn.microsoft.com/en-us/power-bi/transform-model/desktop-relationships-understand#cross-filter-direction
#
# Cross filter options:
#
# - single : allows to summarize fact table by applying filter from dimention table but reverse is not possible.
# - both   : allows to apply filters from both side, here by using **both** filter option i cant summrize product table(dim table) by using filter from sales table(fact table) (filter column: price)

# %% [markdown]
# ![crossfilterdirection.png](attachment:crossfilterdirection.png)
