# %% [markdown]
# **What is applied steps in Power query editor?**

# %% [markdown]
# 🔗 **Power BI Basics: What Are Applied Steps in Power Query Editor?**
#
# Hello, Power BI enthusiasts! 🌟 As I continue to explore Power BI, today I’m excited to talk about **Applied Steps** in Power Query Editor. This feature is key to understanding and managing your data transformations. Let's dive in!
#
# 1️⃣ **Understanding Applied Steps**: In Power Query Editor, every action you perform on your data is recorded as an "Applied Step." These steps are listed in the **Applied Steps** window on the right side of the editor, providing a chronological log of all transformations.
#
# 2️⃣ **Viewing Applied Steps**:
#    - By clicking on a specific step, you can see how the data looked at that point in the transformation process. This helps in understanding the impact of each transformation and ensures accuracy in your data preparation.
#
# 3️⃣ **Managing Applied Steps**:
#    - **Modify Steps**: You can edit the parameters of a specific step to refine your data transformation.
#    - **Remove Steps**: If a step is no longer needed or causes errors, simply right-click and select **Delete** to remove it.
#    - **Reorder Steps**: Drag and drop steps to change their sequence if the order of transformations needs adjustment.
#
# 4️⃣ **Benefits of Applied Steps**:
#    - **Transparency**: Each transformation is logged, making it easy to track and review changes.
#    - **Flexibility**: Easily modify, delete, or reorder steps without starting over.
#    - **Troubleshooting**: Quickly identify and fix errors by isolating and examining individual steps.
#
# 🔍 **Pro Tip**: Name your steps descriptively to quickly understand the purpose of each transformation, especially when dealing with complex queries.
#
# Stay tuned for more Power BI tips as I continue my learning journey. Feel free to share your thoughts or questions in the comments!
#
# #PowerBI #DataTransformation #PowerQuery #DataAnalytics #BusinessIntelligence #LearningJourney #DataScience

# %% [markdown]
# ![AppliedSteps.png](attachment:AppliedSteps.png)

# %% [markdown]
# ## Basic Data Transformations

# %% [markdown]
# **how to rename columns ?**

# %% [markdown]
# if we found columns with wrong header, spelling mistakes in header, header naming convention is not consistent or user friendly then we have to rename column.
#
# we can either right click on header and select rename option to rename or just double click on header and overwrite the name.

# %% [markdown]
# ![rename_column.png](attachment:rename_column.png)

# %% [markdown]
# **how to remove columns ?**

# %% [markdown]
# it better to remove unnessasary column as early as possible. removing unnessary columns will help to focus on data what we need and improve overall performance of power bi
#
# one way is to only keep required column on data sourrce example if we are taking sql data, keep required column in select statement.
#
# In power bi you can remove columns in two ways.
#
# 1. select columns which need to remove and click on remove columns or select required columns and select remove other columns option
#
# 2. other way is to choose columns which we needs by selecting choose columns option.

# %% [markdown]
# ![remove_Columns.png](attachment:remove_Columns.png)

# %% [markdown]
# **How to remove top rows ?**

# %% [markdown]
# if u found some rows on top of data are blank or invalid according to data then you can opt remove top rows under remove rows menu.

# %% [markdown]
# ![remove_first_rows.png](attachment:remove_first_rows.png)

# %% [markdown]
# **How to Promote row as headers ?**

# %% [markdown]
# When a table is created in Power BI Desktop, Power Query Editor assumes that all data belongs in table rows. However, a data source might have a first row that contains column names. To correct this inaccuracy, you need to promote the first table row into column headers.
#
#
# we can use **First Row as Headers option** on the Home tab or by selecting dropdown button in the top left corner of table and then  selecting **Use First Row as Headers.**

# %% [markdown]
# ![promote_first_row.png](attachment:promote_first_row.png)

# %% [markdown]
# **How to replace values ?**
#
# right click on the column then select **Replace values...** option which will popup below window
#
# we can also replace values with "null" as well.

# %% [markdown]
# ![replace_values.png](attachment:replace_values.png)

# %% [markdown]
# **How to change type of a column ?**

# %% [markdown]
# click on the top left corner of a column will pop up a list of datatypes we can select from there.

# %% [markdown]
# ![change_type.png](attachment:change_type.png)

# %% [markdown]
# It is very imp to identify datatype correctly , else we can't plot charts, measures, custom columns correctly.
#
# Power query engine will automatically identified the type of each column.
#
# ![identift_type.png](attachment:identift_type.png)
#
# But if the data is not cleaned this auto detection will not work correctly so we need to clean data and make power bi to detect again by clicking **Detect Data Type** option under transform menu.

# %% [markdown]
# **How to remove duplicates?**

# %% [markdown]
# we can remove duplicate values from columns.
#
# note that removing duplicates from one column will effect that row as well.
#
# as well as duplicates values of that column will be removed also row of that specific duplicate values will also be removed.
#
# so identifiying a unique column is imp.

# %% [markdown]
# ![remove_duplicates.png](attachment:remove_duplicates.png)

# %% [markdown]
# ## Append queries and Merge queries

# %% [markdown]
# 🔗 **Power BI Basics: Append Queries and Merge Queries**
#
# Hello, Power BI enthusiasts! 🌟 Today, I’m excited to share how to append and merge queries in Power Query Editor. These techniques are essential for combining data from multiple sources. Let’s dive in!
#
# ### **1️⃣ Append Queries**
#
# Appending queries involves adding rows of data from one table to another. It’s crucial to ensure that all tables/queries have the same structure before appending.
#
# - **Preparation**: Remove any unwanted columns and ensure all headers are consistent and correctly named.
#
# - **Steps to Append Queries**:
#   - Navigate to the **Home** tab in Power Query Editor.
#   - Select the **Append Queries** dropdown.
#     - **Append Queries as New**: This creates a new table/query with the appended result.
#     - **Append Queries**: This appends another table/query to the main table.
#
# ### **2️⃣ Merge Queries**
#
# Merging queries combines data from multiple tables based on a common column, similar to SQL joins.
#
# - **Steps to Merge Queries**:
#   - Navigate to the **Home** tab in Power Query Editor.
#   - Select the **Merge Queries** dropdown.
#     - **Merge Queries**: This merges another table/query into the main table.
#     - **Merge Queries as New**: This creates a new table/query with the merged result.
#   - A new window will open where you can select the tables and the common column.
#   - Choose the type of join (similar to SQL join clauses):
#     - **Left Outer**: Includes all rows from the first table and matching rows from the second table.
#     - **Full Outer**: Includes all rows from both tables.
#     - **Inner**: Includes only the rows that have matching values in both tables.
#
# 🔍 **Pro Tip**: Always verify the structure and consistency of your data before appending or merging to avoid errors and ensure accurate results.
#
# Stay tuned for more Power BI tips and techniques as I continue my learning journey. Your feedback and questions are always welcome!
#
# #PowerBI #DataTransformation #AppendQueries #MergeQueries #DataAnalytics #BusinessIntelligence #LearningJourney #DataScience

# %% [markdown]
# ![append_1.png](attachment:append_1.png)

# %% [markdown]
# ![merge_queries.png](attachment:merge_queries.png)

# %% [markdown]
# ## Pivot and Unpivot Columns

# %% [markdown]
# check pivot and unpivot session in below link.
#
# https://learn.microsoft.com/en-us/training/modules/clean-data-power-bi/2-shape-data
#
# **Pivot Columns** converts rows to columns and aggrigate its values.
#
# **Unpivot Columns** Converts columns in to rows.

# %% [markdown]
# ![pivot_unpivot_table.png](attachment:pivot_unpivot_table.png)

# %% [markdown]
# In above example 2021 and 2022 shows cost in year 2021 and 2022. but the issue is if we need to find total cost in total(both 2021 and 2022) it will be dificult.
#
# so we can organize the table by Unpivoting the table in better way.So lets unpivot columns 2021 and 2022.

# %% [markdown]
# ![unpivoting.png](attachment:unpivoting.png)

# %% [markdown]
# we have to rename columns after **Unpivoting**

# %% [markdown]
# In the above table consider we need to identify cost based on **Costs for employees** and **Costs for rent**.
#
# In this kind of situation we can use **pivot columns** option.
#
# additionally situations like if we need to find out aggrigated result of a column based on another categorical column we can utilizse **advanced options** feature in **Pivot columns**

# %% [markdown]
# ![pivoting_process.png](attachment:pivoting_process.png)

# %% [markdown]
# In the above image explains how to pivot a table.
#
# step1: select the column to pivot.
#
# step2: Home tab in power query ribbon click **pivot column**
#
# step3: in th popped up window select the value column. value can be aggrigated or non aggrigated,
#
#     - if value is non aggrigated like just another column then we can directly select in **Values Column** drop down option
#
#     - if value is aggrigated we can use **Advanced Options**
#
# step4: OK

# %% [markdown]
# Table after pivoting.

# %% [markdown]
# ![Table_after_pivoting.png](attachment:Table_after_pivoting.png)
