# %% [markdown]
# **How to connect to a data source?**

# %% [markdown]
# 🔗 **Power BI Basics: How to Connect to a Data Source**
#
# Hello, Power BI enthusiasts! 🌟 As I am learning Power BI, I'd love to share some basic yet essential steps on connecting to a data source. Whether you're just starting out or need a quick refresher, this guide will help you get started. Let's jump in!
#
# 1️⃣ **Home Menu**: Open Power BI and navigate to the **Home** menu.
#
# 2️⃣ **Get Data**: Click on the **Get Data** option. This will bring up a list of various data sources you can connect to.
#
# 3️⃣ **Select Data Source**: From the list that pops up, select the data source you need. Whether it's Excel, SQL Server, a web page, or any other source, Power BI has you covered.
#
# 4️⃣ **Browse for File**: If you're connecting to a file, browse to its location on your computer and select it.
#
# 5️⃣ **Preview Data**: Power BI will load a preview of your data. This is a great opportunity to ensure you're pulling in the right information.
#
# 6️⃣ **Load or Transform**: You can either:
#    - **Load**: Directly load the data into Power BI for immediate use.
#    - **Transform**: Choose to transform the data using Power Query Editor if you need to clean or modify it before loading.
#
# 🔍 **Pro Tip**: Using the **Transform** option is powerful as it allows you to shape your data to fit your analysis needs perfectly.
#
# Stay tuned for more Power BI tips and tricks as I continue my learning journey! 💡 Feel free to share your thoughts or questions in the comments below.
#
# #PowerBI #DataAnalytics #BusinessIntelligence #LearningJourney #DataScience

# %% [markdown]
# ![data_source.png](attachment:data_source.png)

# %% [markdown]
#     -- Resources ::
#
#         https://learn.microsoft.com/en-us/training/modules/get-data/2-data-files

# %% [markdown]
# **How to Change the Data Source of a Loaded Data ?**

# %% [markdown]
# 🔗 **Power BI Basics: How to Change the Data Source of a Loaded Data**
#
# Hello, Power BI enthusiasts! 🌟 As I continue my journey with Power BI, I’ve learned how crucial it is to maintain the connection to your data sources. Here’s a quick guide on how to update the data source if the file location changes:
#
# 1️⃣ **Understand the Need**: If your file storage location changes, you must update the file connection path in Power BI to keep your report up to date. Failing to do so will result in an error when refreshing your data: **file could not be found**.
#
# 2️⃣ **Access Data Source Settings**:
#    - Open Power BI and go to **Home**.
#    - Select **Transform Data** to open the Power Query Editor.
#    - In the Power Query Editor, click on **Data Source settings**.
#
# 3️⃣ **Change the Source Path**:
#    - In the Data Source Settings window, locate the file you need to update and click on **Change Source**.
#    - Update the file path manually or use the **Browse** option to locate your file.
#    - Click **OK** to confirm the changes, and then select **Close**.
#
# 🔍 **Pro Tip**: Keeping your data source paths organized and consistent can save you a lot of time and prevent errors in your reports.
#
# Stay tuned for more Power BI tips and tricks as I continue to explore and learn. Your thoughts and questions are always welcome in the comments!
#
# #PowerBI #DataManagement #DataAnalytics #BusinessIntelligence #LearningJourney #DataScience

# %% [markdown]
#     -- Resources ::
#
#         https://learn.microsoft.com/en-us/training/modules/get-data/2-data-files

# %% [markdown]
# ![Data_Source_settings.png](attachment:Data_Source_settings.png)

# %% [markdown]
# **How to navigate to power query editor?**

# %% [markdown]
# Home --> click on Transfrom Data --> which will navigate to power query editor window.
