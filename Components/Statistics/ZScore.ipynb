# %% [markdown]
# # Z Score

# %% [markdown]
# 1. Z score brings a ND to a SND, so it brings mue to 0 and sigma to 1
#
# 2. So by using integration on PDF equation(for SND) with lowerlimit and upper limit of zscore we can find AUC or prob.
#
# 3.
#
#
# $$
# {
# {\huge f(x) = \int_{-\infty}^{+\infty} \frac{1} {  \sqrt{2  \pi}} {e^\frac{-(x)^2} {2}} \,dx }
# }
# $$
# $$
# {\mu = 0 \newline \sigma = 1 \newline \pi = 3.14 \newline e = 2.71}
# $$
#
#
# 4.
#
# ![Zscore1.png](attachment:27183c3f-cd6d-4b7a-b511-bfcb2eb3878c.png)
#
# 5. We can use integration to find AUC but for easy calculation we use Z-table
#
# 6. Area to right is 1-(Area to left)
#
#     AR=1-AL
#     AR+AL=1
#
# 7. in z table area given will be always from left.
#
# 8. Z score qun = (x-𝜇)/𝜎
#
#     if we are using CLT ZScore = (x-𝜇)/(𝜎/√n)
#
#     where (𝜎/√n) is known as Standard error
