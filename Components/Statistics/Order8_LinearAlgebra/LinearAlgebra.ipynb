# %% [markdown]
# # Linear Algebra

# %% [markdown]
# 1. with linear algebra we can scale to any dimention of data, human can visualize only up to 3D,but with Linear Algebra we can mathematically calculate more any dimentional of data.
#
# 2. it help defining datapoints(features) as vector

# %% [markdown]
# ## Qualtities

# %%
1. Scalar: Scalar only have magnitude. eg: distance

2. Vector: Vector have mag as well as direction. eg: displacement.

# %% [markdown]
# ## Distance between two points

# %% [markdown]
# 1. Euclidean distance
#
# 2. Manhatten distance
#
# 3. Minkowski distance

# %% [markdown]
# ### Euclidean distance or L2 Norm

# %% [markdown]
# **Distance between a point and origin**
#
# ![eclidianfromorigin.png](attachment:fd738e6a-6e86-48fd-a753-d2d4a2f584c4.png)
#
# **Distance between a point and origin in hyperplane**
#
#  $$
#  {\huge d=\sqrt{a^2+b^2+c^2+.......+n^2}}
#  $$
#
# **Distance between two points**
# ![elidiandistance.png](attachment:8dcee70a-304a-4171-ac31-5f4def7e6f16.png)
#
# $$
# {\huge d= { (\sum_{i=1}^{n} {|x_{1i}-x_{2i}|^2} })^{1/2} }
# $$

# %% [markdown]
# ### Manhatten distance or L1 Norm

# %% [markdown]
# ![manhattendistance.png](attachment:df529ed8-8058-4c20-be26-9ba42138aa27.png)
#
#
# 1. Manhatten distance is not direct distance(diagonal distance) between between two points. its a distance from point x to y like in above given pic
#
# 2. **Euclidean distance is the shortest path between source and destination which is a straight line but Manhattan distance is sum of all the real distances between source(s) and destination(d) and each distance are always the straight lines.**
#
# $$
# {\huge d= { \sum_{i=1}^{n} {|x_{1i}-x_{2i}|} } }
# $$

# %% [markdown]
# <h1 style="color:red">Why Manhattan distance is preferred in high dimensional data?<h1>

# %% [markdown]
# ### Minkowski distance or LP Norm

# %% [markdown]
# 1. Minkowski distance is a generalization of the Euclidean distance and the Manhattan distance. Minkowski distance is applied in machine learning to find out distance similarity. If C = 1 it is Manhattan Distance. If C = 2 It is Euclidean distance.

# %% [markdown]
# ![minkowski.png](attachment:9004c37c-73e6-4357-88fd-ef1a63c9aef8.png)

# %% [markdown]
# ## Vector Multiplication

# %% [markdown]
# 1. dot product : gives **Scalar value**
#
# 2. cross product: gives **direction**

# %% [markdown]
# 1. default vector: By default a vector is **column vector**
#
# 2. row vector: a vector with n elements which only have One row and n columns is **row vector**

# %% [markdown]
# ### Dot Product in LinearAlgebra

# %% [markdown]
# $$
# {
# {\huge a=[a_1,a_2,a_3,a_4,........,a_n]}
# \newline
# {\huge b=[b_1,b_2,b_3,b_4,........,b_n]}
# \newline
# {\huge a^T.b=[a_1b_1+a_2b_2+a_3b_3+.......+a_nb_n]}
# }
# $$
#
# where a and b are default vectors a^T.b also write as a.b (but understant a is a^T)

# %% [markdown]
# ### Angle between vectors

# %% [markdown]
# ![adotb.png](attachment:7c5e2c62-ac95-4c1c-8fae-a215d53e7619.png)
#
# ||a||: distance from origin to (a1,a2)
#
# ||b||: distance from origin to (b1,b2)
#
# **In geometry or we can say in terms of angle :**
#
# a.b=||a|| ||a|| Cos theta
#
# **In Linear algebra:**
#
# a.b (a^T.b)= [a1b1+a2b2]

# %% [markdown]
# ### Projection

# %% [markdown]
# ![projection.png](attachment:0277c49a-6e8e-436f-af0a-dfcd22efa047.png)

# %% [markdown]
# ### Unit Vector

# %% [markdown]
# ![UnitVector.png](attachment:7d5c5b1c-65f4-4215-8b1c-526b680aea48.png)

# %% [markdown]
# ## Line, Plane and Hyperplane

# %% [markdown]
# check doc linear algebra

# %% [markdown]
# ## Eigen Value and Eigen Vector

# %% [markdown]
# 1. After linear transformation of a vector  direction remains same(means vector does not rotate) then its eigen vector.
#
# 2. lambda: value by which original vector scaled up
#
# 3. Ax=lamda*x
#
#     where x is the vector
#
#     A is the matrix used to Linear transformation on vector x
#
#     Ax is the transformation
#
#     lambda is the eigen value
#
#     x is the eigen vector (vector x's directtion remains same)
