# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# Hypothesis: Beliefs/Assumptions
#
# Testing: Checking
#
#
# Null hypo(H0): existing belief or Assumption
#
# Alternative hypo(Ha): Opposiing H0

# %% [markdown]
# **Q1.** Police clams that a person is a criminal
#
# Ho: he is not criminal.
#
# Ha: he is criminal.

# %% [markdown]
# **Q2.** Bride Clams that groom has taken dowry
#
# Ho: groom not taken dowry.
#
# Ha: Groom taken dowry.

# %% [markdown]
# **Q3.** Indian going to win world cup
#
# H0: any other team will win.
#
# Ha: India will win

# %% [markdown]
# **Q4.** I Claim avg salaty of a data scientist changed from 5lakh.
#
# h0: mue = 5 lakh
#
# Ha: mue != 5 lakh

# %% [markdown]
# ## Confidence Interval

# %% [markdown]
# 1. A confidence interval is the mean of your estimate plus and minus the variation in that estimate.
#
# 2. this variation in estimate also known as **Margin of error** (Z*(𝜎/√n))
#
# 3. UL= 𝜇 + Z*(𝜎/√n).  LL = 𝜇 + Z*(𝜎/√n)
#
# 4. Confidence Intervel aka acceptence region or Tollerence region.
#
# 5. Rejection region=1 -CI
#
# 6. **Exceptence region hypothesys method:**
#
#     ![Acceptenceregionmethod.png](attachment:46e07645-8eb0-43d6-8cbc-62db91389872.png)
#
# 7. **One Tailed Test vs Two tailed Test**
#
#     If **RR lies only on One side of graph** then its One tailed test.
#
#     If **RR lies only on Both sides of graph** then its two tailed test.
#
#     ![OneTailTwotail.png](attachment:cbd5cec5-195a-4344-bcc7-183cc9860514.png)

# %% [markdown]
# **Critical Value method**
#
# 1. Significance level(alpha): its is a level where rejection region starts
#
# 2. In Critical value method we use critical value aka Significance level (alpha) to identify RR.
#
# 3. default value of alpha is 5% or 0.05
#
# 4. Critical value method 2 tail test:
#
#     ![CriticalValuetwotail.png](attachment:61bcdd5e-c10a-4bb4-a79b-ba9377b60965.png)
#
# 5. Critical value method One tail test:
#
#     ![CriticalvalueOnetail.png](attachment:ae2ab0c5-5ecf-44cb-8646-8c01caa0d7e9.png)
#
#
# 6. Steps for AR Method and Critical Value method:
#
#     ![ARmethodCRVmethod.png](attachment:8d092ebb-ffcc-4e73-b431-7a9575c27fc5.png)

# %% [markdown]
# **P-Value Method (Most Imp):**
#
# 1. Probability of ur H0 to be true.
#
# 2. here we compaire P-value (prob value or AUC value) with alpha aka SL
#
# 3. if P-val < alpha then reject H0
#
# 4. If p-val > alpha then failed to reject H0

# %% [markdown]
# ## Refer HT-Numerical.pdf for sample question 1

# %% [markdown]
# **Q2** refer HT-Numerical.pdf
#
# **AR method**
#
# H0:Mue=0
#
# Ha: mue!=0
#
# x'=.1% = .001
#
# sample std=.25%
#
# CI=95% so alpha=.05
#
# LL= Mue-Z*sigma/sqrt(n) = 0-1.96*(.0025/sqrt(250)) = -.000309
#
# UL= Mue+Z*sigma/sqrt(n)= 0+1.96*(.0025/sqrt(250)) =.000309
#
# n=250
#
# X' lies out side of -.000309 to .000309 so reject null hypo.
#
# **Critical val method**
#
# H0:Mue=0
#
# Ha: mue!=0
#
# cv1=-1.96(for alpha .025)
#
# cv2=1.96(for alpha .025)
#
# z-cal=(.001-0)/(.0025/sqrt(250)) =6.32
#
# which is greater than -1.96 to 1.96
#
# **Pval Method**
#
# Z-cal= 6.32 (1-z-tab) will  be close to zero wich will be < .05 so reject H0

# %% [markdown]
# # T DIstribution

# %% [markdown]
# ![Tdist.png](attachment:358e905c-635d-4ef5-9ca8-635bde1bf5f8.png)

# %% [markdown]
# 1. we use T dist
#
#     - when we have less sample size <30
#
#     - low confidence
#
#     - tails will be thicker in T -dist leads to increase in  CI Area
#
#     - Degree of freedom Logically independent values(example 1,2,3,4,5,x and mean 10 so x 5 independnt values and x is depedent)
#
#     - for n values df will be n-1.

# %% [markdown]
# **Q3.** refer HT-Numerical.pdf
#
# H0:mue>=2
#
# Ha:mue <2
#
# df=9,std=.15,x'=1.8
#
# n=10
#
# tcal=(1.8-2)/(.15/sqrt(10))= -4.21
#
# t-tab=2.821
#
# tcal < t-tab : H0 rejected.
